# %%
import torch
import matplotlib.pyplot as plt

a = torch.randn(300) * 1e-7

plt.hist(a, bins=20)
# Out:
# (array([ 2.,  2.,  2.,  3., 11., 13., 14., 15., 23., 40., 46., 23., 32.,
#         27., 13.,  8., 12.,  8.,  4.,  2.]),
#  array([-2.66267733e-07, -2.40660569e-07, -2.15053404e-07, -1.89446254e-07,
#         -1.63839090e-07, -1.38231925e-07, -1.12624775e-07, -8.70176109e-08,
#         -6.14104465e-08, -3.58032821e-08, -1.01961177e-08,  1.54110467e-08,
#          4.10181826e-08,  6.66253470e-08,  9.22325114e-08,  1.17839676e-07,
#          1.43446840e-07,  1.69054005e-07,  1.94661169e-07,  2.20268333e-07,
#          2.45875498e-07]),
#  <BarContainer object of 20 artists>)
